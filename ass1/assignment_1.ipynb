# %% [markdown]
# # Assignment 1 by Lena Schemet
# Datum: 16.11.2022
# Erstellerin: Lena Schemet

# %% [markdown]
# ## Training 2b)
# ### ConvNext_Tiny Net first run
#
# ssh://mmc-user@gimpel.informatik.uni-augsburg.de:6224/home/mmc-user/mmc/bin/python -u /home/mmc-user/remote_assi_1/main.py
# Experiment will be started!
# start date and time = 15/11/2022 13:22:33
# Used device:  cuda
# Seeds are set!
# Start loading ImageDataSet...
# Split dataset into train and validation set...
# Total training images: 12519
# Total validation images: 8346
# Used Model:  ConvNext
# Start training...
# Current epoch:  0
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:12<00:00,  1.29s/it]
# Training of epoch 0 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:41<00:00, 37.76it/s]
# Validation of epoch 0 completed.
# Training acc: 0.690
# Validation acc: 0.937
# Saved best PyTorch Model State to output/model_weights_2b.pth
# Evaluation succeeded
# Current epoch:  1
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:38<00:00,  1.42s/it]
# Training of epoch 1 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:35<00:00, 38.69it/s]
# Validation of epoch 1 completed.
# Training acc: 0.962
# Validation acc: 0.958
# Saved best PyTorch Model State to output/model_weights_2b.pth
# Evaluation succeeded
# Current epoch:  2
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:19<00:00,  1.33s/it]
# Training of epoch 2 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:42<00:00, 37.52it/s]
# Validation of epoch 2 completed.
# Training acc: 0.992
# Validation acc: 0.972
# Saved best PyTorch Model State to output/model_weights_2b.pth
# Evaluation succeeded
# Current epoch:  3
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:36<00:00,  1.41s/it]
# Training of epoch 3 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:44<00:00, 37.15it/s]
# Validation of epoch 3 completed.
# Training acc: 0.998
# Validation acc: 0.972
# Evaluation succeeded
# Current epoch:  4
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:40<00:00,  1.43s/it]
# Training of epoch 4 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:33<00:00, 39.06it/s]
# Validation of epoch 4 completed.
# Training acc: 0.999
# Validation acc: 0.972
# Evaluation succeeded
# Current epoch:  5
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:53<00:00,  1.50s/it]
# Training of epoch 5 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [04:09<00:00, 33.49it/s]
# Validation of epoch 5 completed.
# Training acc: 0.999
# Validation acc: 0.974
# Saved best PyTorch Model State to output/model_weights_2b.pth
# Evaluation succeeded
# Current epoch:  6
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:51<00:00,  1.49s/it]
# Training of epoch 6 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:35<00:00, 38.72it/s]
# Validation of epoch 6 completed.
# Training acc: 0.999
# Validation acc: 0.974
# Saved best PyTorch Model State to output/model_weights_2b.pth
# Evaluation succeeded
# Current epoch:  7
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:56<00:00,  1.51s/it]
# Training of epoch 7 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:50<00:00, 36.20it/s]
# Validation of epoch 7 completed.
# Training acc: 1.000
# Validation acc: 0.971
# Evaluation succeeded
# Current epoch:  8
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:13<00:00,  1.29s/it]
# Training of epoch 8 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:37<00:00, 38.29it/s]
# Validation of epoch 8 completed.
# Training acc: 0.999
# Validation acc: 0.971
# Evaluation succeeded
# Current epoch:  9
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:33<00:00,  1.39s/it]
# Training of epoch 9 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [04:53<00:00, 28.48it/s]
# Validation of epoch 9 completed.
# Training acc: 0.996
# Validation acc: 0.956
# Evaluation succeeded
# Current epoch:  10
# Training
# 100%|█████████████████████████████████████████| 196/196 [05:50<00:00,  1.79s/it]
# Training of epoch 10 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [05:04<00:00, 27.41it/s]
# Validation of epoch 10 completed.
# Training acc: 0.994
# Validation acc: 0.958
# Evaluation succeeded
# Current epoch:  11
# Training
# 100%|█████████████████████████████████████████| 196/196 [06:05<00:00,  1.86s/it]
# Training of epoch 11 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:40<00:00, 37.86it/s]
# Validation of epoch 11 completed.
# Training acc: 0.995
# Validation acc: 0.962
# Evaluation succeeded
# Current epoch:  12
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:37<00:00,  1.42s/it]
# Training of epoch 12 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:38<00:00, 38.18it/s]
# Validation of epoch 12 completed.
# Training acc: 0.997
# Validation acc: 0.968
# Evaluation succeeded
# Current epoch:  13
# Training
# 100%|█████████████████████████████████████████| 196/196 [05:57<00:00,  1.83s/it]
# Training of epoch 13 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [04:16<00:00, 32.58it/s]
# Validation of epoch 13 completed.
# Training acc: 0.998
# Validation acc: 0.963
# Evaluation succeeded
# Current epoch:  14
# Training
# 100%|█████████████████████████████████████████| 196/196 [03:57<00:00,  1.21s/it]
# Training of epoch 14 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [04:21<00:00, 31.93it/s]
# Validation of epoch 14 completed.
# Training acc: 0.997
# Validation acc: 0.967
# Evaluation succeeded
# Current epoch:  15
# Training
# 100%|█████████████████████████████████████████| 196/196 [05:39<00:00,  1.73s/it]
# Training of epoch 15 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:17<00:00, 42.19it/s]
# Validation of epoch 15 completed.
# Training acc: 0.998
# Validation acc: 0.970
# Evaluation succeeded
# Current epoch:  16
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:05<00:00,  1.25s/it]
# Training of epoch 16 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:44<00:00, 37.24it/s]
# Validation of epoch 16 completed.
# Training acc: 0.999
# Validation acc: 0.973
# Evaluation succeeded
# Current epoch:  17
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:25<00:00,  1.35s/it]
# Training of epoch 17 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:24<00:00, 40.83it/s]
# Validation of epoch 17 completed.
# Training acc: 0.999
# Validation acc: 0.969
# Evaluation succeeded
# Current epoch:  18
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:16<00:00,  1.31s/it]
# Training of epoch 18 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:54<00:00, 35.66it/s]
# Validation of epoch 18 completed.
# Training acc: 0.996
# Validation acc: 0.961
# Evaluation succeeded
# Current epoch:  19
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:51<00:00,  1.49s/it]
# Training of epoch 19 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:57<00:00, 35.18it/s]
# Validation of epoch 19 completed.
# Training acc: 0.996
# Validation acc: 0.967
# Evaluation succeeded
# Current epoch:  20
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:10<00:00,  1.28s/it]
# Training of epoch 20 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:13<00:00, 43.05it/s]
# Validation of epoch 20 completed.
# Training acc: 0.999
# Validation acc: 0.975
# Saved best PyTorch Model State to output/model_weights_2b.pth
# Evaluation succeeded
# Current epoch:  21
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:45<00:00,  1.45s/it]
# Training of epoch 21 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:34<00:00, 53.98it/s]
# Validation of epoch 21 completed.
# Training acc: 0.998
# Validation acc: 0.963
# Evaluation succeeded
# Current epoch:  22
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:23<00:00,  1.36it/s]
# Training of epoch 22 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:02<00:00, 68.03it/s]
# Validation of epoch 22 completed.
# Training acc: 0.998
# Validation acc: 0.971
# Evaluation succeeded
# Current epoch:  23
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:45<00:00,  1.18it/s]
# Training of epoch 23 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:02<00:00, 67.96it/s]
# Validation of epoch 23 completed.
# Training acc: 0.998
# Validation acc: 0.967
# Evaluation succeeded
# Current epoch:  24
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:35<00:00,  1.26it/s]
# Training of epoch 24 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:08<00:00, 64.87it/s]
# Validation of epoch 24 completed.
# Training acc: 0.999
# Validation acc: 0.970
# Evaluation succeeded
# Current epoch:  25
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:15<00:00,  1.45it/s]
# Training of epoch 25 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [01:40<00:00, 83.00it/s]
# Validation of epoch 25 completed.
# Training acc: 1.000
# Validation acc: 0.973
# Evaluation succeeded
# Current epoch:  26
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:06<00:00,  1.55it/s]
# Training of epoch 26 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [01:43<00:00, 80.65it/s]
# Validation of epoch 26 completed.
# Training acc: 0.999
# Validation acc: 0.965
# Evaluation succeeded
# Current epoch:  27
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:05<00:00,  1.57it/s]
# Training of epoch 27 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [01:45<00:00, 78.94it/s]
# Validation of epoch 27 completed.
# Training acc: 0.999
# Validation acc: 0.973
# Evaluation succeeded
# Current epoch:  28
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:04<00:00,  1.58it/s]
# Training of epoch 28 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [01:51<00:00, 74.68it/s]
# Validation of epoch 28 completed.
# Training acc: 0.999
# Validation acc: 0.965
# Evaluation succeeded
# Current epoch:  29
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:09<00:00,  1.51it/s]
# Training of epoch 29 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [01:31<00:00, 91.24it/s]
# Validation of epoch 29 completed.
# Training acc: 0.998
# Validation acc: 0.970
# Evaluation succeeded

# %% [markdown]
# ## Run 2a & 2b
# Erstes Netz: Resnet mit Parametern aus 2a)
# Zweites Netz: ConvNext_Tiny mit Parameters aus 2b)
# Beide ausgewertet mit der Mean per class accuracy
#
# ssh://mmc-user@gimpel.informatik.uni-augsburg.de:6224/home/mmc-user/mmc/bin/python -u /home/mmc-user/.pycharm_helpers/pydev/pydevd.py --multiproc --qt-support=auto --client 0.0.0.0 --port 42923 --file /home/mmc-user/remote_assi_1/main.py
# Connected to pydev debugger (build 213.7172.26)
# Experiment will be started!
# start date and time =  15/11/2022 20:38:54
# Used device:  cuda
# Seeds are set!
# Start loading ImageDataSet...
# Split dataset into train and validation set...
# Total training images: 12519
# Total validation images: 8346
# Used Model:  ResNet18
# Start training...
# Current epoch:  1
# Training
# 100%|█████████████████████████████████████████| 196/196 [05:53<00:00,  1.81s/it]
# Training of epoch 1 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [05:34<00:00, 24.96it/s]
# Validation of epoch 1 completed.
# Training acc: 0.418
# Validation acc: 0.624
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  2
# Training
# 100%|█████████████████████████████████████████| 196/196 [05:59<00:00,  1.84s/it]
# Training of epoch 2 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [04:13<00:00, 32.94it/s]
# Validation of epoch 2 completed.
# Training acc: 0.785
# Validation acc: 0.777
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  3
# Training
# 100%|█████████████████████████████████████████| 196/196 [05:45<00:00,  1.76s/it]
# Training of epoch 3 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [04:25<00:00, 31.48it/s]
# Validation of epoch 3 completed.
# Training acc: 0.971
# Validation acc: 0.815
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  4
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:47<00:00,  1.46s/it]
# Training of epoch 4 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [04:48<00:00, 28.95it/s]
# Validation of epoch 4 completed.
# Training acc: 0.999
# Validation acc: 0.832
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  5
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:51<00:00,  1.49s/it]
# Training of epoch 5 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:49<00:00, 36.36it/s]
# Validation of epoch 5 completed.
# Training acc: 1.000
# Validation acc: 0.831
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  6
# Training
# 100%|█████████████████████████████████████████| 196/196 [05:09<00:00,  1.58s/it]
# Training of epoch 6 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [04:24<00:00, 31.60it/s]
# Validation of epoch 6 completed.
# Training acc: 1.000
# Validation acc: 0.832
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  7
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:16<00:00,  1.31s/it]
# Training of epoch 7 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [04:32<00:00, 30.60it/s]
# Validation of epoch 7 completed.
# Training acc: 1.000
# Validation acc: 0.832
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  8
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:59<00:00,  1.53s/it]
# Training of epoch 8 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:57<00:00, 35.21it/s]
# Validation of epoch 8 completed.
# Training acc: 1.000
# Validation acc: 0.828
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  9
# Training
# 100%|█████████████████████████████████████████| 196/196 [05:21<00:00,  1.64s/it]
# Training of epoch 9 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [05:28<00:00, 25.41it/s]
# Validation of epoch 9 completed.
# Training acc: 1.000
# Validation acc: 0.832
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  10
# Training
# 100%|█████████████████████████████████████████| 196/196 [06:14<00:00,  1.91s/it]
# Training of epoch 10 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [05:35<00:00, 24.90it/s]
# Validation of epoch 10 completed.
# Training acc: 1.000
# Validation acc: 0.840
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  11
# Training
# 100%|█████████████████████████████████████████| 196/196 [06:40<00:00,  2.04s/it]
# Training of epoch 11 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [04:58<00:00, 28.00it/s]
# Validation of epoch 11 completed.
# Training acc: 1.000
# Validation acc: 0.833
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  12
# Training
# 100%|█████████████████████████████████████████| 196/196 [06:08<00:00,  1.88s/it]
# Training of epoch 12 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [05:10<00:00, 26.85it/s]
# Validation of epoch 12 completed.
# Training acc: 1.000
# Validation acc: 0.833
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  13
# Training
# 100%|█████████████████████████████████████████| 196/196 [05:43<00:00,  1.75s/it]
# Training of epoch 13 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [05:05<00:00, 27.30it/s]
# Validation of epoch 13 completed.
# Training acc: 1.000
# Validation acc: 0.839
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  14
# Training
# 100%|█████████████████████████████████████████| 196/196 [03:33<00:00,  1.09s/it]
# Training of epoch 14 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:03<00:00, 45.54it/s]
# Validation of epoch 14 completed.
# Training acc: 1.000
# Validation acc: 0.834
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  15
# Training
# 100%|█████████████████████████████████████████| 196/196 [03:04<00:00,  1.06it/s]
# Training of epoch 15 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:48<00:00, 49.64it/s]
# Validation of epoch 15 completed.
# Training acc: 1.000
# Validation acc: 0.838
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  16
# Training
# 100%|█████████████████████████████████████████| 196/196 [03:05<00:00,  1.06it/s]
# Training of epoch 16 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:11<00:00, 43.68it/s]
# Validation of epoch 16 completed.
# Training acc: 1.000
# Validation acc: 0.839
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  17
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:30<00:00,  1.38s/it]
# Training of epoch 17 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:50<00:00, 36.22it/s]
# Validation of epoch 17 completed.
# Training acc: 1.000
# Validation acc: 0.838
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  18
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:36<00:00,  1.41s/it]
# Training of epoch 18 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [04:02<00:00, 34.42it/s]
# Validation of epoch 18 completed.
# Training acc: 1.000
# Validation acc: 0.840
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  19
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:27<00:00,  1.36s/it]
# Training of epoch 19 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:58<00:00, 34.97it/s]
# Validation of epoch 19 completed.
# Training acc: 1.000
# Validation acc: 0.841
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  20
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:29<00:00,  1.38s/it]
# Training of epoch 20 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:57<00:00, 35.15it/s]
# Validation of epoch 20 completed.
# Training acc: 1.000
# Validation acc: 0.841
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  21
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:38<00:00,  1.42s/it]
# Training of epoch 21 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:49<00:00, 36.44it/s]
# Validation of epoch 21 completed.
# Training acc: 1.000
# Validation acc: 0.840
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  22
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:41<00:00,  1.44s/it]
# Training of epoch 22 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [04:12<00:00, 33.06it/s]
# Validation of epoch 22 completed.
# Training acc: 1.000
# Validation acc: 0.841
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  23
# Training
# 100%|█████████████████████████████████████████| 196/196 [03:00<00:00,  1.08it/s]
# Training of epoch 23 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:57<00:00, 35.19it/s]
# Validation of epoch 23 completed.
# Training acc: 1.000
# Validation acc: 0.845
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  24
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:25<00:00,  1.36s/it]
# Training of epoch 24 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [04:07<00:00, 33.66it/s]
# Validation of epoch 24 completed.
# Training acc: 1.000
# Validation acc: 0.841
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  25
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:19<00:00,  1.33s/it]
# Training of epoch 25 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [04:06<00:00, 33.86it/s]
# Validation of epoch 25 completed.
# Training acc: 1.000
# Validation acc: 0.844
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  26
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:23<00:00,  1.34s/it]
# Training of epoch 26 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [04:11<00:00, 33.17it/s]
# Validation of epoch 26 completed.
# Training acc: 1.000
# Validation acc: 0.837
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  27
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:14<00:00,  1.30s/it]
# Training of epoch 27 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:52<00:00, 35.85it/s]
# Validation of epoch 27 completed.
# Training acc: 1.000
# Validation acc: 0.839
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  28
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:24<00:00,  1.36it/s]
# Training of epoch 28 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:27<00:00, 56.41it/s]
# Validation of epoch 28 completed.
# Training acc: 1.000
# Validation acc: 0.838
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  29
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:00<00:00,  1.62it/s]
# Training of epoch 29 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:27<00:00, 56.44it/s]
# Validation of epoch 29 completed.
# Training acc: 1.000
# Validation acc: 0.842
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  30
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:15<00:00,  1.45it/s]
# Training of epoch 30 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:44<00:00, 50.82it/s]
# Validation of epoch 30 completed.
# Training acc: 1.000
# Validation acc: 0.846
# Saving model ...
# Saving model ...
# Saving model ...
# Saving model ...
# Done!
# Experiment will be started!
# start date and time =  16/11/2022 00:58:23
# Used device:  cuda
# Seeds are set!
# Start loading ImageDataSet...
# Split dataset into train and validation set...
# Total training images: 12519
# Total validation images: 8346
# Used Model:  ConvNext
# Start training...
# Current epoch:  1
# Training
# 100%|█████████████████████████████████████████| 196/196 [03:14<00:00,  1.01it/s]
# Training of epoch 1 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:08<00:00, 44.35it/s]
# Validation of epoch 1 completed.
# Training acc: 0.401
# Validation acc: 0.708
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  2
# Training
# 100%|█████████████████████████████████████████| 196/196 [04:00<00:00,  1.23s/it]
# Training of epoch 2 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:28<00:00, 40.09it/s]
# Validation of epoch 2 completed.
# Training acc: 0.834
# Validation acc: 0.878
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  3
# Training
# 100%|█████████████████████████████████████████| 196/196 [03:19<00:00,  1.02s/it]
# Training of epoch 3 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:31<00:00, 39.48it/s]
# Validation of epoch 3 completed.
# Training acc: 0.972
# Validation acc: 0.927
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  4
# Training
# 100%|█████████████████████████████████████████| 196/196 [03:24<00:00,  1.04s/it]
# Training of epoch 4 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:54<00:00, 47.80it/s]
# Validation of epoch 4 completed.
# Training acc: 0.990
# Validation acc: 0.923
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  5
# Training
# 100%|█████████████████████████████████████████| 196/196 [03:39<00:00,  1.12s/it]
# Training of epoch 5 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:56<00:00, 47.22it/s]
# Validation of epoch 5 completed.
# Training acc: 0.998
# Validation acc: 0.922
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  6
# Training
# 100%|█████████████████████████████████████████| 196/196 [03:29<00:00,  1.07s/it]
# Training of epoch 6 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:26<00:00, 40.51it/s]
# Validation of epoch 6 completed.
# Training acc: 0.998
# Validation acc: 0.928
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  7
# Training
# 100%|█████████████████████████████████████████| 196/196 [03:03<00:00,  1.07it/s]
# Training of epoch 7 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:09<00:00, 44.15it/s]
# Validation of epoch 7 completed.
# Training acc: 0.995
# Validation acc: 0.931
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  8
# Training
# 100%|█████████████████████████████████████████| 196/196 [03:16<00:00,  1.00s/it]
# Training of epoch 8 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:18<00:00, 42.06it/s]
# Validation of epoch 8 completed.
# Training acc: 0.997
# Validation acc: 0.915
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  9
# Training
# 100%|█████████████████████████████████████████| 196/196 [03:25<00:00,  1.05s/it]
# Training of epoch 9 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:02<00:00, 45.68it/s]
# Validation of epoch 9 completed.
# Training acc: 0.995
# Validation acc: 0.932
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  10
# Training
# 100%|█████████████████████████████████████████| 196/196 [03:34<00:00,  1.09s/it]
# Training of epoch 10 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [03:05<00:00, 44.90it/s]
# Validation of epoch 10 completed.
# Training acc: 0.982
# Validation acc: 0.908
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  11
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:20<00:00,  1.40it/s]
# Training of epoch 11 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:06<00:00, 66.06it/s]
# Validation of epoch 11 completed.
# Training acc: 0.991
# Validation acc: 0.919
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  12
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:11<00:00,  1.49it/s]
# Training of epoch 12 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:07<00:00, 65.61it/s]
# Validation of epoch 12 completed.
# Training acc: 0.997
# Validation acc: 0.928
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  13
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:09<00:00,  1.51it/s]
# Training of epoch 13 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:07<00:00, 65.58it/s]
# Validation of epoch 13 completed.
# Training acc: 0.998
# Validation acc: 0.910
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  14
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:10<00:00,  1.50it/s]
# Training of epoch 14 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:06<00:00, 66.02it/s]
# Validation of epoch 14 completed.
# Training acc: 0.991
# Validation acc: 0.919
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  15
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:08<00:00,  1.53it/s]
# Training of epoch 15 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:05<00:00, 66.58it/s]
# Validation of epoch 15 completed.
# Training acc: 0.996
# Validation acc: 0.917
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  16
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:11<00:00,  1.50it/s]
# Training of epoch 16 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:06<00:00, 66.21it/s]
# Validation of epoch 16 completed.
# Training acc: 0.990
# Validation acc: 0.897
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  17
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:11<00:00,  1.49it/s]
# Training of epoch 17 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:05<00:00, 66.74it/s]
# Validation of epoch 17 completed.
# Training acc: 0.992
# Validation acc: 0.931
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  18
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:10<00:00,  1.50it/s]
# Training of epoch 18 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:06<00:00, 66.04it/s]
# Validation of epoch 18 completed.
# Training acc: 0.998
# Validation acc: 0.930
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  19
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:09<00:00,  1.51it/s]
# Training of epoch 19 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:07<00:00, 65.48it/s]
# Validation of epoch 19 completed.
# Training acc: 0.998
# Validation acc: 0.919
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  20
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:14<00:00,  1.46it/s]
# Training of epoch 20 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:07<00:00, 65.67it/s]
# Validation of epoch 20 completed.
# Training acc: 1.000
# Validation acc: 0.934
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  21
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:09<00:00,  1.52it/s]
# Training of epoch 21 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:08<00:00, 65.07it/s]
# Validation of epoch 21 completed.
# Training acc: 0.995
# Validation acc: 0.932
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  22
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:08<00:00,  1.52it/s]
# Training of epoch 22 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:04<00:00, 66.79it/s]
# Validation of epoch 22 completed.
# Training acc: 0.999
# Validation acc: 0.935
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  23
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:09<00:00,  1.51it/s]
# Training of epoch 23 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:06<00:00, 65.80it/s]
# Validation of epoch 23 completed.
# Training acc: 0.998
# Validation acc: 0.912
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  24
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:09<00:00,  1.52it/s]
# Training of epoch 24 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:08<00:00, 64.81it/s]
# Validation of epoch 24 completed.
# Training acc: 0.994
# Validation acc: 0.912
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  25
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:09<00:00,  1.52it/s]
# Training of epoch 25 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:06<00:00, 65.86it/s]
# Validation of epoch 25 completed.
# Training acc: 0.999
# Validation acc: 0.933
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  26
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:12<00:00,  1.48it/s]
# Training of epoch 26 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:04<00:00, 67.23it/s]
# Validation of epoch 26 completed.
# Training acc: 0.997
# Validation acc: 0.932
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  27
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:10<00:00,  1.51it/s]
# Training of epoch 27 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:08<00:00, 65.12it/s]
# Validation of epoch 27 completed.
# Training acc: 0.999
# Validation acc: 0.940
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  28
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:11<00:00,  1.49it/s]
# Training of epoch 28 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:06<00:00, 66.24it/s]
# Validation of epoch 28 completed.
# Training acc: 0.994
# Validation acc: 0.947
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  29
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:09<00:00,  1.52it/s]
# Training of epoch 29 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:05<00:00, 66.68it/s]
# Validation of epoch 29 completed.
# Training acc: 0.998
# Validation acc: 0.931
# Saving model ...
# Saving model ...
# Saving model ...
# Current epoch:  30
# Training
# 100%|█████████████████████████████████████████| 196/196 [02:11<00:00,  1.49it/s]
# Training of epoch 30 completed.
# Validation
# 100%|███████████████████████████████████████| 8346/8346 [02:05<00:00, 66.69it/s]
# Validation of epoch 30 completed.
# Training acc: 0.999
# Validation acc: 0.937
# Saving model ...
# Saving model ...
# Saving model ...
# Saving model ...
# Done!
#
# Process finished with exit code 0
